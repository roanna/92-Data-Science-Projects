# %%
import pandas as pd
import spacy

nlp = spacy.load("de_core_news_lg")
file_path = r"data\Goethe Wortliste A2.csv"

df_inp = pd.read_csv(file_path, header=0, delimiter="|")
dfv = pd.read_csv(r"data\clean_verbs.csv")

# %% [markdown]
# Importing file w/ sentences and dropping useless columns, leaving only ones with sentences in it.

# %%
# Dropping every column exept for the sentences
df_inp = df_inp.drop(["Audio_Wort", "Word_DE", "Word_EN", "Plural", "Hinweis", "Verbformen", "S1_EN", "S2_EN", "S3_EN", "S4_EN"], axis=1)
print("Total number of sentences: ", df_inp.S1_DE.nunique() + df_inp.S2_DE.nunique() + df_inp.S3_DE.nunique() + df_inp.S4_DE.nunique())

df1 = df_inp[["S1_DE"]].rename(columns={"S1_DE": "sentence"})
df2 = df_inp[["S2_DE"]].rename(columns={"S2_DE": "sentence"})
df3 = df_inp[["S3_DE"]].rename(columns={"S3_DE": "sentence"})
df4 = df_inp[["S4_DE"]].rename(columns={"S4_DE": "sentence"})
df_s = pd.concat([df1, df2, df3, df4], ignore_index=True).dropna().drop_duplicates().reset_index().drop("index", axis=1)
print("Total number of sentences in concated DF: ", len(df_s))
# Out:
# Total number of sentences:  1180
# Total number of sentences in concated DF:  1178

# %%
df_w = pd.DataFrame({"word":[], "lemma_predicted":[], "pos": [], "morph": []})

# print("╔════════════════════════════════════╦══════════╦══════════╗")
# print(f"{'║    word':<16} => {' lemma':<16} ║ {'pos':<8} ║ {'morph    ║'}")
# print("╚════════════════════════════════════╩══════════╩══════════╝")
for sentence in df_s.loc[df_s.index, "sentence"]:
    for token in nlp(sentence):
        # print(f"{token.text:<16} => {token.lemma_:<16} | {token.pos_:<8} | {token.morph}")
        new_word = {
            "word": token.text,
            "pos": token.pos_,
            "lemma_predicted": token.lemma_,
            "morph": token.morph}
        df_w.loc[len(df_w)] = new_word

df_w = dfv[["word", "lemma"]].merge(df_w, on="word", how="right")
df_w.head(10)
# Out:
#        word     lemma lemma_predicted    pos  \
# 0      Darf    dürfen          dürfen    AUX
# 1       ich       NaN             ich   PRON
# 2     Ihnen       NaN           ihnen   PRON
# 3       ein       NaN             ein    DET
# 4     Stück       NaN           Stück   NOUN
# 5    Kuchen       NaN          Kuchen   NOUN
# 6  anbieten  anbieten        anbieten   VERB
# 7         ?       NaN              --  PUNCT
# 8       Ich       NaN             ich   PRON
# 9      muss    müssen          mussen    AUX
#
#                                                morph
# 0  (Mood=Ind, Number=Sing, Person=1, Tense=Pres, ...
# 1    (Case=Nom, Number=Sing, Person=1, PronType=Prs)
# 2    (Case=Dat, Number=Sing, Person=2, PronType=Prs)
# 3  (Case=Acc, Definite=Ind, Gender=Neut, Number=S...
# 4               (Case=Acc, Gender=Neut, Number=Sing)
# 5               (Case=Acc, Gender=Masc, Number=Sing)
# 6                                     (VerbForm=Inf)
# 7                                                 ()
# 8    (Case=Nom, Number=Sing, Person=1, PronType=Prs)
# 9  (Mood=Ind, Number=Sing, Person=1, Tense=Pres, ...

# %%
mask = (df_w["pos"].isin(["AUX", "VERB"])) & (df_w["lemma"]==df_w["lemma_predicted"])
df_w[mask]["lemma"].nunique() / df_w[df_w["pos"].isin(["AUX", "VERB"])]["lemma_predicted"].nunique()
# Out:
# 0.7873417721518987

# %%
# testing various attributes
for sentence in df_s.loc[:1, "sentence"]:
    for token in nlp(sentence):
        print(f"{token.text:<16} => {token.lemma_:<16} | {token.pos_:<8} | {token.tag_}")
# Out:
# Darf             => dürfen           | AUX      | VMFIN
# ich              => ich              | PRON     | PPER
# Ihnen            => ihnen            | PRON     | PPER
# ein              => ein              | DET      | ART
# Stück            => Stück            | NOUN     | NN
# Kuchen           => Kuchen           | NOUN     | NN
# anbieten         => anbieten         | VERB     | VVINF
# ?                => --               | PUNCT    | $.
# Ich              => ich              | PRON     | PPER
# muss             => mussen           | AUX      | VMFIN
# meinen           => mein             | DET      | PPOSAT
# Schlüssel        => Schlüssel        | NOUN     | NN
# an               => an               | ADP      | APPR
# der              => der              | DET      | ART
# Rezeption        => Rezeption        | NOUN     | NN
# abgeben          => abgeben          | VERB     | VVINF
# .                => --               | PUNCT    | $.

# %% [markdown]
# ### Importing database from dwds

# %%
dwds_df = pd.read_csv(r"data\dwds_korpora.csv")

# %%
dwds_df = dwds_df.drop(["transliterated_text", "cab_normalized_text"], axis=1)
dwds_df.info()

# %% [markdown]
# #### Cleaning corpora dataset from foreign words, symbols and numbers.

# %%
dwds_df["pos"].unique()
# Out:
# array(['$.', '$(', 'NN', 'ADJA', 'NE', 'FM.fr', 'FM', 'XY', 'CARD',
#        'TRUNC', 'VVINF', 'APPR', 'ADV', 'FM.xy', 'FM.en', 'ART', 'FM.es',
#        'FM.la', 'FM.nl', 'FM.sv', 'PPER', 'FM.da', 'FM.it', 'FM.el', '$,',
#        'VAFIN', 'ADJD', 'VVIZU', 'VVFIN', 'VVPP', 'VMFIN', 'APPRART',
#        'PTKVZ', 'KON', 'KOKOM', 'KOUS', 'PIAT', 'PTKA', 'APZR', 'ITJ',
#        'VVIMP', 'PIS', 'PDS', 'PAV', 'KOUI', 'PTKANT', 'VMINF', 'PRELS',
#        'PDAT', 'PPOSAT', 'PWAV', 'PPOSS', 'PRF', 'PWS', 'PTKNEG', 'VAIMP',
#        'PWAT', 'PTKZU', 'PRELAT', 'APPO', 'VAPP', 'VMPP', 'VAINF'],
#       dtype=object)

# %% [markdown]
# CARD - Kardinalzahl

# %%
# Dropping duplicates, NaN and useless columns
dwds_df = dwds_df.dropna().drop_duplicates().drop(["transliterated_text", "cab_normalized_text"], axis=1)

# %%
mask = (
    dwds_df["pos"].str.contains("^XY|^\$\.|^\$\(|^FM|^\$\,|CARD", regex=True, case=False) |
    dwds_df["utf8_text"].str.contains("^[\W\d]+$|^[\W]{0,2}[\wöäüßÖÄÜ]{1,2}$|[^\wöäüßÖÄÜ]|^\d+|\d", regex=True, case=False)
    )
dwds_df = dwds_df[~mask]
print(len(dwds_df))
dwds_df = dwds_df.reset_index(drop=True)
dwds_df = dwds_df.drop(index=range(0,260)).reset_index(drop=True)
dwds_df.head(50)

# %%
df_test = dwds_df[["utf8_text", "lemma"]].merge(df_w, left_on="utf8_text", right_on="word", how="right")

mask = (df_test["pos"].isin(["AUX", "VERB"])) & (df_test["lemma_x"]!=df_test["lemma_y"])
df_test[mask]["lemma_y"].nunique() / df_test[df_test["pos"].isin(["AUX", "VERB"])]["lemma_x"].nunique()
# Out:
# 0.26628895184135976

# %%
len(df_test[mask])
# Out:
# 284

# %% [markdown]
# Importing Text

# %%
text_file_path = r"data\tintenherz_text.txt"
df1 = pd.DataFrame({"word":[], "lemma_spacy":[], "pos": [], "morph": []})

with open(text_file_path) as f:
    text = f.read().replace("\n\n", " ").replace("\n", " ")
    chapters = text.split("## ")[1:]

doc = nlp(chapters[0])
sentences = list(doc.sents)

for s in sentences:
    # print(s)
    for token in s:
        # print(f"{token.text:<16} => {token.lemma_:<16} | {token.pos_:<8} | {token.tag_}")
        new_word = {
            "word": token.text,
            "pos": token.pos_,
            "lemma_spacy": token.lemma_,
            "morph": token.morph}
        df1.loc[len(df1)] = new_word

df1 = dfv[["word", "lemma"]].merge(df1, on="word", how="right")
mask = df1["pos"].isin(["AUX", "VERB"]) & -df1["lemma"].isna()
df1["comp"] = df1.apply(lambda x: True if x["lemma"]==x["lemma_spacy"] else False, axis=1)

# %%
print("Correct predictions ratio:", df1[mask].comp.sum() / len(df1[mask]))
# only show different rows
mask_different_rows = -df1["comp"] & df1["pos"].isin(["AUX", "VERB"])
df1[mask_different_rows].head(50)
# Out:
# Correct predictions ratio: 0.9347826086956522
#             word   lemma  lemma_spacy   pos  \
# 22        musste  müssen       mussen   AUX
# 42      klopften     NaN      klopfen  VERB
# 48        bellte     NaN       bellen  VERB
# 69        drehte     NaN       drehen  VERB
# 74           lag     NaN       liegen  VERB
# 85       drückte     NaN      drücken  VERB
# 101       locken     NaN       locken  VERB
# 137    entdeckte     NaN    entdecken  VERB
# 140          Gib   geben          gib  VERB
# 144     flüstert     NaN     flüstern  VERB
# 161  geantwortet     NaN    antworten  VERB
# 179     gezwickt     NaN      zwicken  VERB
# 189      genannt     NaN       nennen  VERB
# 199       begann     NaN     beginnen  VERB
# 207      änderte     NaN       ändern  VERB
# 209          lag     NaN       liegen  VERB
# 227       setzte     NaN       setzen  VERB
# 232         rieb     NaN         rieb  VERB
# 240          zog     NaN       ziehen  VERB
# 250   raschelten     NaN    raschelen  VERB
# 256    aufschlug     NaN  aufschlagen  VERB
# 259         fand     NaN       finden  VERB
# 270        klang     NaN      klingen  VERB
# 278       wusste     NaN       wussen  VERB
# 291       musste  müssen       mussen   AUX
# 307    versteckt     NaN   verstecken  VERB
# 316   anzuzünden     NaN     anzünden  VERB
# 319       mochte     NaN        mögen  VERB
# 325       frisst     NaN      frissen  VERB
# 329        sagte     NaN        sagen  VERB
# 346    aufpassen     NaN    aufpassen  VERB
# 349       liebte     NaN       lieben  VERB
# 370        hielt     NaN       halten  VERB
# 389      pustete     NaN       pusten  VERB
# 404    erinnerte     NaN     erinnern  VERB
# 408       kniete     NaN        knien  VERB
# 415      blickte     NaN      blicken  VERB
# 420          sah     NaN        sehen  VERB
# 443    leuchtete     NaN     leuchten  VERB
# 450       klebte     NaN       kleben  VERB
# 459      triefte     NaN      triefen  VERB
# 466    beachtete     NaN     beachten  VERB
# 471        stand     NaN       stehen  VERB
# 480  geschlungen     NaN    schlungen  VERB
# 491       wärmen     NaN       wärmen  VERB
# 494      starrte     NaN      starren  VERB
# 502         muss  müssen       mussen   AUX
# 512        blieb     NaN      bleiben  VERB
# 520      starrte     NaN      starren  VERB
# 528        hätte     NaN        haben   AUX
#
#                                                  morph   comp
# 22   (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 42   (Mood=Ind, Number=Plur, Person=3, Tense=Past, ...  False
# 48   (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 69   (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 74   (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 85   (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 101                                     (VerbForm=Inf)  False
# 137  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 140                  (Mood=Imp, Number=Sing, Person=2)  False
# 144  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...  False
# 161                                    (VerbForm=Part)  False
# 179                                    (VerbForm=Part)  False
# 189                                    (VerbForm=Part)  False
# 199  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 207  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 209  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 227  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 232  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 240  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 250  (Mood=Ind, Number=Plur, Person=3, Tense=Past, ...  False
# 256  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 259  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 270  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 278  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 291  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 307                                    (VerbForm=Part)  False
# 316                                     (VerbForm=Inf)  False
# 319  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 325  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...  False
# 329  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 346                                     (VerbForm=Inf)  False
# 349  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 370  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 389  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 404  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 408  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 415  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 420  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 443  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 450  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 459  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 466  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 471  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 480                                    (VerbForm=Part)  False
# 491                                     (VerbForm=Inf)  False
# 494  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 502  (Mood=Ind, Number=Sing, Person=1, Tense=Pres, ...  False
# 512  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 520  (Mood=Ind, Number=Sing, Person=3, Tense=Past, ...  False
# 528  (Mood=Sub, Number=Sing, Person=3, Tense=Past, ...  False
